# %%
import cv2
import numpy as np
import pandas as pd
import random
import glob
import csv
import keras
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# #### Create function for tiles images

# %%
def tiles_images(img, pieces):
    img_width = img_height = img.shape[1] // pieces
    tiles_img = [img[x:x+img_height,y:y+img_width]
                 for x in range(0,img.shape[0], img_height)
                 for y in range(0,img.shape[1],img_width)
                ]
    
    new_tiles = []
    
    for img in tiles_img:
        if img.shape[0] == img_width and  img.shape[1] == img_height:
            new_tiles.append(img)

    return new_tiles

# %% [markdown]
# #### Create function for group images

# %%
def group_image(images, shuffle_arr, pieces=4):
    img = []
    
    new_array = [shuffle_arr[i] for i in shuffle_arr]
    print(new_array)
    new_order =  [images[i] for i in new_array]
    
    for i in range(pieces):
        img.append(np.concatenate(new_order[i*pieces:(i+1)*pieces], axis=1))
    
    img = np.concatenate(img, axis=0)
    return img

# %%
def load_data(base_path, path, pieces=2):
    data = pd.read_csv(base_path + '{}.csv'.format(path))
    path = base_path + path + '/'

    x, y = [], []
    for i in range(len(data)):
        im = Image.open(path + str(i) + '.jpg')
        im = np.array(im).astype('float16')
        im = im / 255 - 0.5
        
        if path.split('/')[-2] == 'test':
            x.append(im)
        else:
            x.append(tiles_images(im, pieces))

        label = data.iloc[i]
        label = [int(i) for i in label]
        y.append(label)

    return (np.array(x), np.expand_dims(np.array(y), axis=-1))

# %% [markdown]
# Define base path

# %%
base_path = "../input/jigsaw-puzzle/Gravity Falls/puzzle_2x2/"

# %% [markdown]
# #### Download data for train, test and validation

# %%
x_train, y_train = load_data(base_path, 'train')

# %%
x_val, y_val = load_data(base_path, 'valid')

# %%
x_test, y_test = load_data(base_path, 'test')

# %% [markdown]
# ### Train model for puzzle 2x2

# %%
import keras
from keras.layers import TimeDistributed as td
from keras.layers import Conv2D, Flatten, Dense, ZeroPadding2D, Activation
from keras.layers import MaxPooling2D, Dropout, BatchNormalization, Reshape

# %%
def get_model():

    model = keras.models.Sequential()

    model.add(td(ZeroPadding2D(2), input_shape=(4, 112, 112, 3)))

    model.add(td(Conv2D(50, kernel_size=(5,5), padding='same', activation='relu', strides=2)))
    model.add(td(BatchNormalization()))
    model.add(td(MaxPooling2D()))

    model.add(td(Conv2D(100, kernel_size=(5,5), padding='same', activation='relu', strides=2)))
    model.add(td(BatchNormalization()))
    model.add(td(Dropout(0.3)))

    model.add(td(Conv2D(100, kernel_size=(3,3), padding='same', activation='relu', strides=2)))
    model.add(td(BatchNormalization()))
    model.add(td(Dropout(0.3)))

    model.add(td(Conv2D(200, kernel_size=(3,3), padding='same', activation='relu', strides=1)))
    model.add(td(BatchNormalization()))
    model.add(td(Dropout(0.3)))

    model.add(Flatten())

    model.add(Dense(600, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(400, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(16))
    model.add(Reshape((4, 4)))
    model.add(Activation('softmax'))

    return model

# %%
model = get_model()

# %%
adam = keras.optimizers.Adam(learning_rate=.001)
model.compile(optimizer=adam, loss='sparse_categorical_crossentropy',
              metrics = ['sparse_categorical_accuracy'])

# %%
x_train.shape
# Out:
# (440, 4, 112, 112, 3)

# %%
y_train.shape
# Out:
# (440, 4, 1)

# %%
model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 21s 3s/step - loss: 1.9497 - sparse_categorical_accuracy: 0.3256 - val_loss: 1.3527 - val_sparse_categorical_accuracy: 0.4045
# Epoch 2/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.8585 - sparse_categorical_accuracy: 0.6687 - val_loss: 1.3072 - val_sparse_categorical_accuracy: 0.4045
# Epoch 3/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.5218 - sparse_categorical_accuracy: 0.8085 - val_loss: 1.3035 - val_sparse_categorical_accuracy: 0.3773
# Epoch 4/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.3116 - sparse_categorical_accuracy: 0.8949 - val_loss: 1.2688 - val_sparse_categorical_accuracy: 0.4136
# Epoch 5/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.1977 - sparse_categorical_accuracy: 0.9352 - val_loss: 1.2815 - val_sparse_categorical_accuracy: 0.4045
# Epoch 6/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.1338 - sparse_categorical_accuracy: 0.9614 - val_loss: 1.2578 - val_sparse_categorical_accuracy: 0.4614
# Epoch 7/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0976 - sparse_categorical_accuracy: 0.9716 - val_loss: 1.2712 - val_sparse_categorical_accuracy: 0.3909
# Epoch 8/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0741 - sparse_categorical_accuracy: 0.9830 - val_loss: 1.3126 - val_sparse_categorical_accuracy: 0.3773
# Epoch 9/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9943 - val_loss: 1.3012 - val_sparse_categorical_accuracy: 0.3545
# Epoch 10/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0374 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.3266 - val_sparse_categorical_accuracy: 0.3591
# Epoch 11/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9955 - val_loss: 1.3748 - val_sparse_categorical_accuracy: 0.4045
# Epoch 12/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9966 - val_loss: 1.4746 - val_sparse_categorical_accuracy: 0.3500
# Epoch 13/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9989 - val_loss: 1.5128 - val_sparse_categorical_accuracy: 0.3159
# Epoch 14/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0149 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4531 - val_sparse_categorical_accuracy: 0.3750
# Epoch 15/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0153 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.3931 - val_sparse_categorical_accuracy: 0.4114
# Epoch 16/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9983 - val_loss: 1.3323 - val_sparse_categorical_accuracy: 0.4432
# Epoch 17/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0114 - sparse_categorical_accuracy: 0.9989 - val_loss: 1.3589 - val_sparse_categorical_accuracy: 0.4023
# Epoch 18/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9983 - val_loss: 1.3054 - val_sparse_categorical_accuracy: 0.4659
# Epoch 19/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0091 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2930 - val_sparse_categorical_accuracy: 0.4818
# Epoch 20/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0084 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.3531 - val_sparse_categorical_accuracy: 0.4727
# Epoch 21/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0071 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4278 - val_sparse_categorical_accuracy: 0.4227
# Epoch 22/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0053 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4843 - val_sparse_categorical_accuracy: 0.3818
# Epoch 23/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9989 - val_loss: 1.4224 - val_sparse_categorical_accuracy: 0.4000
# Epoch 24/100
# 7/7 [==============================] - 18s 2s/step - loss: 0.0054 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2967 - val_sparse_categorical_accuracy: 0.4386
# Epoch 25/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.2579 - val_sparse_categorical_accuracy: 0.4364
# Epoch 26/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.2158 - val_sparse_categorical_accuracy: 0.4568
# Epoch 27/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0050 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2416 - val_sparse_categorical_accuracy: 0.4591
# Epoch 28/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0034 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2730 - val_sparse_categorical_accuracy: 0.4500
# Epoch 29/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.2805 - val_sparse_categorical_accuracy: 0.4636
# Epoch 30/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.2905 - val_sparse_categorical_accuracy: 0.4500
# Epoch 31/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.2781 - val_sparse_categorical_accuracy: 0.4795
# Epoch 32/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0035 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2424 - val_sparse_categorical_accuracy: 0.5068
# Epoch 33/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0038 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2454 - val_sparse_categorical_accuracy: 0.5159
# Epoch 34/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0030 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2347 - val_sparse_categorical_accuracy: 0.5114
# Epoch 35/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0031 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2333 - val_sparse_categorical_accuracy: 0.5273
# Epoch 36/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0028 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.2023 - val_sparse_categorical_accuracy: 0.5295
# Epoch 37/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0028 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1619 - val_sparse_categorical_accuracy: 0.5500
# Epoch 38/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0024 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1750 - val_sparse_categorical_accuracy: 0.5591
# Epoch 39/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0022 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1838 - val_sparse_categorical_accuracy: 0.5500
# Epoch 40/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0026 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1552 - val_sparse_categorical_accuracy: 0.5682
# Epoch 41/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1408 - val_sparse_categorical_accuracy: 0.5773
# Epoch 42/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0020 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1372 - val_sparse_categorical_accuracy: 0.5795
# Epoch 43/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1288 - val_sparse_categorical_accuracy: 0.5841
# Epoch 44/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0023 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1524 - val_sparse_categorical_accuracy: 0.5909
# Epoch 45/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1551 - val_sparse_categorical_accuracy: 0.5841
# Epoch 46/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1555 - val_sparse_categorical_accuracy: 0.5909
# Epoch 47/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1590 - val_sparse_categorical_accuracy: 0.5955
# Epoch 48/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.1363 - val_sparse_categorical_accuracy: 0.6114
# Epoch 49/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0021 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0812 - val_sparse_categorical_accuracy: 0.6250
# Epoch 50/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.0302 - val_sparse_categorical_accuracy: 0.6477
# Epoch 51/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.9361 - val_sparse_categorical_accuracy: 0.6682
# Epoch 52/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0016 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8914 - val_sparse_categorical_accuracy: 0.6795
# Epoch 53/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8627 - val_sparse_categorical_accuracy: 0.6932
# Epoch 54/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8428 - val_sparse_categorical_accuracy: 0.6977
# Epoch 55/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0018 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8191 - val_sparse_categorical_accuracy: 0.7182
# Epoch 56/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8110 - val_sparse_categorical_accuracy: 0.7182
# Epoch 57/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0017 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7977 - val_sparse_categorical_accuracy: 0.7182
# Epoch 58/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7815 - val_sparse_categorical_accuracy: 0.7205
# Epoch 59/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7666 - val_sparse_categorical_accuracy: 0.7318
# Epoch 60/100
# 7/7 [==============================] - 18s 2s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7626 - val_sparse_categorical_accuracy: 0.7409
# Epoch 61/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7555 - val_sparse_categorical_accuracy: 0.7455
# Epoch 62/100
# 7/7 [==============================] - 17s 3s/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7520 - val_sparse_categorical_accuracy: 0.7545
# Epoch 63/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7510 - val_sparse_categorical_accuracy: 0.7591
# Epoch 64/100
# 7/7 [==============================] - 18s 3s/step - loss: 9.3557e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7541 - val_sparse_categorical_accuracy: 0.7523
# Epoch 65/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7573 - val_sparse_categorical_accuracy: 0.7523
# Epoch 66/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7594 - val_sparse_categorical_accuracy: 0.7500
# Epoch 67/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7550 - val_sparse_categorical_accuracy: 0.7614
# Epoch 68/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7439 - val_sparse_categorical_accuracy: 0.7636
# Epoch 69/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7342 - val_sparse_categorical_accuracy: 0.7705
# Epoch 70/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7266 - val_sparse_categorical_accuracy: 0.7682
# Epoch 71/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7553 - val_sparse_categorical_accuracy: 0.7614
# Epoch 72/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7526 - val_sparse_categorical_accuracy: 0.7636
# Epoch 73/100
# 7/7 [==============================] - 17s 3s/step - loss: 9.9353e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7397 - val_sparse_categorical_accuracy: 0.7614
# Epoch 74/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0013 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7290 - val_sparse_categorical_accuracy: 0.7636
# Epoch 75/100
# 7/7 [==============================] - 17s 3s/step - loss: 7.2765e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7212 - val_sparse_categorical_accuracy: 0.7636
# Epoch 76/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7128 - val_sparse_categorical_accuracy: 0.7659
# Epoch 77/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7071 - val_sparse_categorical_accuracy: 0.7750
# Epoch 78/100
# 7/7 [==============================] - 18s 3s/step - loss: 0.0012 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6971 - val_sparse_categorical_accuracy: 0.7818
# Epoch 79/100
# 7/7 [==============================] - 18s 3s/step - loss: 8.0712e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6856 - val_sparse_categorical_accuracy: 0.7932
# Epoch 80/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6767 - val_sparse_categorical_accuracy: 0.7909
# Epoch 81/100
# 7/7 [==============================] - 18s 3s/step - loss: 9.6579e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6702 - val_sparse_categorical_accuracy: 0.8000
# Epoch 82/100
# 7/7 [==============================] - 17s 3s/step - loss: 7.6270e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6676 - val_sparse_categorical_accuracy: 0.8068
# Epoch 83/100
# 7/7 [==============================] - 18s 3s/step - loss: 8.0759e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6668 - val_sparse_categorical_accuracy: 0.8068
# Epoch 84/100
# 7/7 [==============================] - 17s 3s/step - loss: 7.2524e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6634 - val_sparse_categorical_accuracy: 0.8136
# Epoch 85/100
# 7/7 [==============================] - 18s 3s/step - loss: 6.7853e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6594 - val_sparse_categorical_accuracy: 0.8136
# Epoch 86/100
# 7/7 [==============================] - 17s 2s/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6423 - val_sparse_categorical_accuracy: 0.8159
# Epoch 87/100
# 7/7 [==============================] - 18s 3s/step - loss: 7.6967e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6368 - val_sparse_categorical_accuracy: 0.8182
# Epoch 88/100
# 7/7 [==============================] - 18s 3s/step - loss: 7.1757e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6369 - val_sparse_categorical_accuracy: 0.8182
# Epoch 89/100
# 7/7 [==============================] - 17s 2s/step - loss: 9.5776e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6426 - val_sparse_categorical_accuracy: 0.8159
# Epoch 90/100
# 7/7 [==============================] - 18s 3s/step - loss: 6.7000e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6520 - val_sparse_categorical_accuracy: 0.8159
# Epoch 91/100
# 7/7 [==============================] - 17s 2s/step - loss: 8.5398e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6581 - val_sparse_categorical_accuracy: 0.8114
# Epoch 92/100
# 7/7 [==============================] - 17s 3s/step - loss: 6.3293e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6620 - val_sparse_categorical_accuracy: 0.8068
# Epoch 93/100
# 7/7 [==============================] - 17s 2s/step - loss: 6.4951e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6628 - val_sparse_categorical_accuracy: 0.8114
# Epoch 94/100
# 7/7 [==============================] - 18s 3s/step - loss: 6.4080e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6656 - val_sparse_categorical_accuracy: 0.8091
# Epoch 95/100
# 7/7 [==============================] - 17s 2s/step - loss: 6.0485e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6620 - val_sparse_categorical_accuracy: 0.8114
# Epoch 96/100
# 7/7 [==============================] - 18s 3s/step - loss: 7.3376e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6563 - val_sparse_categorical_accuracy: 0.8114
# Epoch 97/100
# 7/7 [==============================] - 18s 3s/step - loss: 7.7222e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6558 - val_sparse_categorical_accuracy: 0.8114
# Epoch 98/100
# 7/7 [==============================] - 17s 2s/step - loss: 5.9421e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6549 - val_sparse_categorical_accuracy: 0.8136
# Epoch 99/100
# 7/7 [==============================] - 18s 3s/step - loss: 6.6566e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6554 - val_sparse_categorical_accuracy: 0.8114
# Epoch 100/100
# 7/7 [==============================] - 17s 3s/step - loss: 6.4787e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6535 - val_sparse_categorical_accuracy: 0.8114

# %% [markdown]
# #### Check how work our model

# %%
i = 2      #for i-th example in test data
image = x_test[i].astype('float64')+.5
plt.imshow(image)

inp = np.expand_dims(tiles_images(x_test[i], pieces=2), axis=0)
y_pred = model.predict(inp)[0]
y_pred = np.argmax(y_pred, axis=1)
print('y_pred = ',y_pred)
# Out:
# 1/1 [==============================] - 0s 388ms/step
# y_pred =  [3 1 0 2]

# %%
tiles = tiles_images(image, pieces=2)
predit_img = group_image(tiles, y_pred, pieces=2)
plt.imshow(predit_img)
# Out:
# [2, 1, 3, 0]

# %%
i = 5      #for i-th example in test data
image = x_test[i].astype('float64')+.5
plt.imshow(image)

inp = np.expand_dims(tiles_images(x_test[i], pieces=2), axis=0)
y_pred = model.predict(inp)[0]
y_pred = np.argmax(y_pred, axis=1)
print('y_pred = ',y_pred)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# y_pred =  [2 1 3 0]

# %%
tiles = tiles_images(image, pieces=2)
predit_img = group_image(tiles, y_pred, pieces=2)
plt.imshow(predit_img)
# Out:
# [3, 1, 0, 2]
